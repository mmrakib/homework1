# %% [markdown]
# # COMP9417 - Homework 1

# %% [markdown]
# Author: Mohammad Mayaz Rakib (z5361151)

# %% [markdown]
# Before we begin, we must first install and import the necessary Python3 packages required for our solutions.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Part A

# %% [markdown]
# We first load in the data required for this problem.

# %%
t_var = np.load("t_var.npy")
y_var = np.load("y_var.npy")

plt.plot(t_var, y_var)
plt.show()

# %% [markdown]
# Consider a function $f$, where,
#
# $$f(x) = \frac{1}{2} || Ax - b ||_2^2 + \frac{\gamma}{2} || x ||_2^2$$
#
# where matrix $A \in \mathbb{R}^{m \times n}$ is defined as,
#
# $$A = \begin{bmatrix}3 & 2 & 0 & -1 \\
# -1 & 3 & 0 & 2 \\
# 0 & -4 & -2 & 7\end{bmatrix}$$
